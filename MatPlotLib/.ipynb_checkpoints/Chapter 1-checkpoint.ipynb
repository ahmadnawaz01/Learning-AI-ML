# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[10,20,15,50]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=["Mon","Tues","Wed","Thur","Fri"]  #x-axis
y=[14,2,8,10,1] #y-axis

plt.plot(x,y)
plt.title("Bakery Sales of the Week")
plt.xlabel("Days per week")
plt.ylabel("Total Sales per day")
plt.show()
