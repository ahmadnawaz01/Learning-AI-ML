# %%
import cv2
import numpy as np

# %%
img=cv2.imread('images/airplane.png')

# %%
cv2.imshow('window',img)
cv2.waitKey(0)
# Out:
# -1

# %%
img.shape
# Out:
# (365, 546, 3)

# %%
img_resize=cv2.resize(img,(256,256))

# %%
cv2.imshow('window',imgf)
cv2.waitKey(0)
# Out:
# -1

# %%
img_re=cv2.resize(img,(img.shape[1]//2,img.shape[0]//2))

# %%
img_re.shape
# Out:
# (182, 273, 3)

# %%
imgf=cv2.flip(img,-1)

# %%
img_crop=img[0:100,0:100]

# %%
cv2.imshow('window',img_crop)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imwrite('aeroplane.png',imgf)
# Out:
# True
