# %%
import numpy as np
import cv2

# %%
img=cv2.imread('images/airplane.png')

# %%
cv2.imshow('window',img)
cv2.waitKey(0)
# Out:
# -1

# %%
drawing=False
ix=-1
iy=-1
def draw(event,x,y,flags,params):
    global flag,ix,iy
    
    if event==1:
        drawing=True
        ix=x
        iy=y
        
    elif event==0:
        if flag==True:
            cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
    elif event==4:
        flag=False
        cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
        

cv2.namedWindow(winname='window')
cv2.setMouseCallback('window',draw)

img=cv2.imread('images/airplane.png')

while True:
    cv2.imshow('window',img)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13, in draw(event, x, y, flags, params)
#      10     iy=y
#      12 elif event==0:
# ---> 13     if flag==True:
#      14         cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
#      15 elif event==4:
#
# NameError: name 'flag' is not defined
