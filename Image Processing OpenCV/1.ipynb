# %%
import cv2
import numpy as np

# %%
img= cv2.imread('images/airplane.png')

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
img.shape
# Out:
# (365, 546, 3)

# %%
cv2.imshow('window',img)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow('window',img_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
img[:,:,2]=0

# %%
cv2.imshow('window',img)
cv2.waitKey(0)
# Out:
# -1

# %%
blue=img[:,:,0]
green=img[:,:,1]
red=img[:,:,2]

# %%
imgages=np.hstack((blue,green,red))

# %%
cv2.imshow('window',imgages)
cv2.waitKey(0)
