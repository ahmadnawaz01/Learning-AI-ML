# %%
la=[1,3,5]
lb=[0,2,4]
c=la+lb
d=sorted(c)
d.reverse()

c[3]=42
d.append(10)
c.append(7)
c.append(8)
c.append(9)

print("c 3 elements = ",c[:3])
print("last elemetn of d =",d[-1])
print("len of d ",len(d))
# Out:
# c 3 elements =  [1, 3, 5]
# last elemetn of d = 10
# len of d  7
